# %% [markdown]
# # Cobrapy Gapfill below
# You should have three differnt models:
# 1. original model (*working_model*)
#     1a. a model with the missing metabolite (*gapped*)
#     1b. a universal model, with added metabolite if not already in (*universal_with_biolog*)
# 2. Run gapfill on *working_model* to find one/more solutions
# 3. gapfill with one solution (*model_gapfilled*)
# 4. Test to make sure the gapfilled working model works (*model_gapfilled.optimize*)
# 5. Save model with metabolite gap filled (*model_gapfilled*)
#
# asssertions to check:
# 1. assert original model grows
# 2. assert that gapped doesn't grow (assert < threshold)
# 3. assert that gapfilled does grow:
# `growth = model.optimize().objective_value
# threshold = 0.2
# assert growth > threshold, f"Growth {growth} was not greater than threshold {threshold}"`

# %%
#import necessary packages and load model
import cobra
import pandas as pd
working_model = cobra.io.read_sbml_model('../GEMS/model_compartment_cleaned.xml')
#check that model grows
working_model.optimize()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 #import necessary packages and load model
# ----> 2 import cobra
#       3 import pandas as pd
#       4 working_model = cobra.io.read_sbml_model('../GEMS/model_compartment_cleaned.xml')
#
# File c:\Users\lint730\GEM_repos\Rhodobacter_sphaeroides_GEMs\concerto\Lib\site-packages\cobra\__init__.py:5
#       1 __author__ = "The cobrapy core development team."
#       2 __version__ = "0.29.1"
# ----> 5 from cobra.core import (
#       6     Configuration,
#       7     DictList,
#       8     Gene,
#       9     Metabolite,
#      10     Model,
#      11     Object,
#      12     Reaction,
#      13     Solution,
#      14     Species,
#      15 )
#      16 from cobra import flux_analysis
#      17 from cobra import io
#
# File c:\Users\lint730\GEM_repos\Rhodobacter_sphaeroides_GEMs\concerto\Lib\site-packages\cobra\core\__init__.py:1
# ----> 1 from cobra.core.configuration import Configuration
#       2 from cobra.core.dictlist import DictList
#       3 from cobra.core.gene import Gene, GPR
#
# File c:\Users\lint730\GEM_repos\Rhodobacter_sphaeroides_GEMs\concerto\Lib\site-packages\cobra\core\configuration.py:13
#       9 from typing import Optional, Tuple, Union
#      11 import appdirs
# ---> 13 from ..exceptions import SolverNotFound
#      14 from ..util.solver import interface_to_str
#      15 from ..util.solver import solvers as SOLVERS
#
# File c:\Users\lint730\GEM_repos\Rhodobacter_sphaeroides_GEMs\concerto\Lib\site-packages\cobra\exceptions.py:3
#       1 """Module for shared exceptions in the Cobra package."""
# ----> 3 import optlang.interface
#       6 class OptimizationError(Exception):
#       7     """Exception for Optimization issues."""
#
# File c:\Users\lint730\GEM_repos\Rhodobacter_sphaeroides_GEMs\concerto\Lib\site-packages\optlang\__init__.py:19
#      17 import traceback
#      18 from optlang._version import get_versions
# ---> 19 from optlang.util import list_available_solvers
#      20 from optlang.interface import statuses
#      21 import optlang.duality
#
# File c:\Users\lint730\GEM_repos\Rhodobacter_sphaeroides_GEMs\concerto\Lib\site-packages\optlang\util.py:27
#      25 import inspect
#      26 from subprocess import check_output
# ---> 27 from optlang import symbolics
#      28 from optlang.symbolics import mul, add, Pow
#      31 def solve_with_glpsol(glp_prob):
#
# File c:\Users\lint730\GEM_repos\Rhodobacter_sphaeroides_GEMs\concerto\Lib\site-packages\optlang\symbolics.py:100
#      97         return Mul(*args)
#      99 else:  # Use sympy
# --> 100     import sympy
#     102     optlang._USING_SYMENGINE = False
#     104     Integer = sympy.Integer
#
# File c:\Users\lint730\GEM_repos\Rhodobacter_sphaeroides_GEMs\concerto\Lib\site-packages\sympy\__init__.py:154
#     112 from .functions import (factorial, factorial2, rf, ff, binomial,
#     113         RisingFactorial, FallingFactorial, subfactorial, carmichael,
#     114         fibonacci, lucas, motzkin, tribonacci, harmonic, bernoulli, bell, euler,
#    (...)
#     135         Znm, elliptic_k, elliptic_f, elliptic_e, elliptic_pi, beta, mathieus,
#     136         mathieuc, mathieusprime, mathieucprime, riemann_xi, betainc, betainc_regularized)
#     138 from .ntheory import (nextprime, prevprime, prime, primerange,
#     139         randprime, Sieve, sieve, primorial, cycle_length, composite,
#     140         compositepi, isprime, divisors, proper_divisors, factorint,
#    (...)
#     151         continued_fraction_iterator, continued_fraction_reduce,
#     152         continued_fraction_convergents, continued_fraction, egyptian_fraction)
# --> 154 from .concrete import product, Product, summation, Sum
#     156 from .discrete import (fft, ifft, ntt, intt, fwht, ifwht, mobius_transform,
#     157         inverse_mobius_transform, convolution, covering_product,
#     158         intersecting_product)
#     160 from .simplify import (simplify, hypersimp, hypersimilar, logcombine,
#     161         separatevars, posify, besselsimp, kroneckersimp, signsimp,
#     162         nsimplify, FU, fu, sqrtdenest, cse, epath, EPath, hyperexpand,
#     163         collect, rcollect, radsimp, collect_const, fraction, numer, denom,
#     164         trigsimp, exptrigsimp, powsimp, powdenest, combsimp, gammasimp,
#     165         ratsimp, ratsimpmodprime)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:991, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1087, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1186, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
#imported from iRSP1140 work with jeremy
import cobra
universal = cobra.Model("universal_reactions") #grabs universal model from cobra
for i in [i.id for i in model.metabolites.f6p_c.reactions]: #iterates through all reactions that f6p is involved in F6p metabolites
    reaction = model.reactions.get_by_id(i)
    universal.add_reactions([reaction.copy()])
    model.remove_reactions([reaction]) #adds f6p reactions to universal model and removes them from our working model
cobra.io.write_sbml_model(universal, "../GEMs/f6p_reactions.xml") #universal model with f6p
cobra.io.write_sbml_model(model, "../GEMs/model_with_f6p_gap.xml") #model without f6p so should not grow

#test to see if model grows
model_with_f6p_gap = cobra.io.read_sbml_model("../GEMs/model_with_f6p_gap.xml")
model_with_f6p_gap.optimize()

#run gapfill to replace removed metabolite into working model: view reactions to add
solutions = gapfill(model_with_f6p_gap, universal, demand_reactions=False)
for reaction in solutions[0]:
    print(reaction.id)

#run gapfill to replace removed metabolite into working model: take first element of solutions and add
f6p_gapfilled = model_with_f6p_gap.copy()
f6p_gapfilled.add_reactions(solutions[0])
cobra.io.write_sbml_model(f6p_gapfilled, "../GEMs/f6p_gapfilled.xml")

#optimize gapfilled model to make sure it grows
f6p_gapfilled.optimize()
#assert to optimize.solutions() compared to final model
# Out:
# 1773

# %% [markdown]
# # OPTIMIZING MODEL

# %%
from cobra.io import load_model
from cobra.flux_analysis import gapfill

# %%
#check a few things about the model: reactions, growth medium
working_model.reactions.get_by_id('EX_cpd00036_e')
cpd = 'EX_cpd00036_e'
cpd.split('_')[1]

working_model.medium
# Out:
# {'EX_cpd00051_e': 1000.0,
#  'EX_cpd00119_e': 1000.0,
#  'EX_cpd00039_e': 1000.0,
#  'EX_cpd00084_e': 1000.0,
#  'EX_cpd00053_e': 1000.0,
#  'EX_cpd00107_e': 1000.0,
#  'EX_cpd00322_e': 1000.0,
#  'EX_cpd00156_e': 1000.0,
#  'EX_cpd00060_e': 1000.0,
#  'EX_cpd00731_e': 1000.0,
#  'EX_cpd00042_e': 1000.0,
#  'EX_cpd00111_e': 1000.0,
#  'EX_cpd00166_e': 1000.0,
#  'EX_cpd00058_e': 1000.0,
#  'EX_cpd00034_e': 1000.0,
#  'EX_cpd00030_e': 1000.0,
#  'EX_cpd10515_e': 1000.0,
#  'EX_cpd00149_e': 1000.0,
#  'EX_cpd00028_e': 1000.0,
#  'EX_cpd00268_e': 1000.0,
#  'EX_cpd00048_e': 1000.0,
#  'EX_cpd11574_e': 1000.0,
#  'EX_cpd00118_e': 1000.0,
#  'EX_cpd00264_e': 1000.0,
#  'EX_cpd00540_e': 1000.0,
#  'EX_cpd00129_e': 1000.0,
#  'EX_cpd00098_e': 1000.0,
#  'EX_cpd00179_e': 1000.0,
#  'EX_cpd00588_e': 1000.0,
#  'EX_cpd00314_e': 1000.0,
#  'EX_cpd00100_e': 1000.0,
#  'EX_cpd00105_e': 1000.0,
#  'EX_cpd00154_e': 1000.0,
#  'EX_cpd00082_e': 1000.0,
#  'EX_cpd00009_e': 1000.0,
#  'EX_cpd00023_e': 1000.0,
#  'EX_cpd00041_e': 1000.0,
#  'EX_cpd00132_e': 1000.0,
#  'EX_cpd00001_e': 1000.0,
#  'EX_cpd00013_e': 1000.0,
#  'EX_cpd00971_e': 1000.0,
#  'EX_cpd00063_e': 1000.0,
#  'EX_cpd00011_e': 1000.0,
#  'EX_cpd00007_e': 1000.0,
#  'EX_cpd00036_e': 1000.0,
#  'EX_cpd00130_e': 1000.0,
#  'EX_cpd00106_e': 1000.0,
#  'EX_cpd00020_e': 1000.0,
#  'EX_cpd00094_e': 1000.0,
#  'EX_cpd03737_e': 1000.0,
#  'EX_cpd00989_e': 1000.0,
#  'EX_cpd03701_e': 1000.0,
#  'EX_cpd03454_e': 1000.0,
#  'EX_cpd00117_e': 1000.0,
#  'EX_cpd00035_e': 1000.0,
#  'EX_cpd00033_e': 1000.0,
#  'EX_cpd00138_e': 1000.0,
#  'EX_cpd15387_e': 1000.0,
#  'EX_cpd00305_e': 1000.0,
#  'EX_cpd10516_e': 1000.0,
#  'EX_cpd00080_e': 1000.0,
#  'EX_cpd00244_e': 1000.0,
#  'EX_cpd00027_e': 1000.0,
#  'EX_cpd00029_e': 1000.0,
#  'EX_cpd00066_e': 1000.0,
#  'EX_cpd00065_e': 1000.0,
#  'EX_cpd00054_e': 1000.0,
#  'EX_cpd00040_e': 1000.0,
#  'EX_cpd00047_e': 1000.0,
#  'EX_cpd00055_e': 1000.0,
#  'EX_cpd00073_e': 1000.0,
#  'EX_cpd00085_e': 1000.0,
#  'EX_cpd00092_e': 1000.0,
#  'EX_cpd00307_e': 1000.0,
#  'EX_cpd00153_e': 1000.0,
#  'EX_cpd00221_e': 1000.0,
#  'EX_cpd00159_e': 1000.0,
#  'EX_cpd00386_e': 1000.0,
#  'EX_cpd00254_e': 1000.0,
#  'EX_cpd00222_e': 1000.0,
#  'EX_cpd00164_e': 1000.0,
#  'EX_cpd00205_e': 1000.0,
#  'EX_cpd00128_e': 1000.0,
#  'EX_cpd00151_e': 1000.0,
#  'EX_cpd00207_e': 1000.0,
#  'EX_cpd00220_e': 1000.0,
#  'EX_cpd00226_e': 1000.0,
#  'EX_cpd00309_e': 1000.0,
#  'EX_cpd00337_e': 1000.0,
#  'EX_cpd03422_e': 1000.0,
#  'EX_cpd00210_e': 1000.0,
#  'EX_cpd00223_e': 1000.0,
#  'EX_cpd00363_e': 1000.0,
#  'EX_cpd11640_e': 1000.0,
#  'EX_cpd01526_e': 1000.0,
#  'EX_cpd00075_e': 1000.0,
#  'EX_cpd00209_e': 1000.0,
#  'EX_cpd00528_e': 1000.0,
#  'EX_cpd00141_e': 1000.0,
#  'EX_cpd01307_e': 1000.0,
#  'EX_cpd00395_e': 1000.0,
#  'EX_cpd00320_e': 1000.0,
#  'EX_cpd01570_e': 1000.0,
#  'EX_cpd01572_e': 1000.0,
#  'EX_cpd03702_e': 1000.0,
#  'EX_cpd00457_e': 1000.0,
#  'EX_cpd00366_e': 1000.0,
#  'EX_cpd00139_e': 1000.0,
#  'EX_cpd00024_e': 1000.0,
#  'EX_cpd00830_e': 1000.0,
#  'EX_cpd00608_e': 1000.0,
#  'EX_cpd01017_e': 1000.0,
#  'EX_cpd01114_e': 1000.0,
#  'EX_cpd01157_e': 1000.0,
#  'EX_cpd02547_e': 1000.0,
#  'EX_cpd01700_e': 1000.0,
#  'EX_cpd00169_e': 1000.0,
#  'EX_cpd00239_e': 1000.0,
#  'EX_cpd00104_e': 1000.0,
#  'EX_cpd00218_e': 1000.0,
#  'EX_cpd31000_e': 1000.0,
#  'EX_cpd08021_e': 1000.0,
#  'EX_cpd00450_e': 1000.0,
#  'EX_cpd00116_e': 1000.0,
#  'EX_cpd00147_e': 1000.0,
#  'EX_cpd00229_e': 1000.0,
#  'EX_cpd00324_e': 1000.0,
#  'EX_cpd00432_e': 1000.0,
#  'EX_cpd00604_e': 1000.0,
#  'EX_cpd01078_e': 1000.0,
#  'EX_cpd01587_e': 1000.0,
#  'EX_cpd04122_e': 1000.0,
#  'EX_cpd00162_e': 1000.0,
#  'EX_cpd01311_e': 1000.0,
#  'EX_cpd03091_e': 1000.0,
#  'EX_cpd00067_e': 1000.0,
#  'EX_cpd03285_e': 1000.0,
#  'EX_cpd00434_e': 1000.0,
#  'EX_cpd00567_e': 1000.0,
#  'EX_cpd00081_e': 1000.0,
#  'EX_cpd03561_e': 1000.0,
#  'EX_cpd01502_e': 1000.0,
#  'EX_CPD1278_e': 1000.0,
#  'EX_cpd01363_e': 1000.0,
#  'EX_cpd01200_e': 1000.0,
#  'EX_cpd00666_e': 1000.0,
#  'EX_cpd00607_e': 1000.0,
#  'EX_cpd11594_e': 1000.0,
#  'EX_cpd00489_e': 1000.0,
#  'EX_cpd00374_e': 1000.0,
#  'EX_cpd00361_e': 1000.0,
#  'EX_cpd00339_e': 1000.0,
#  'EX_cpd00308_e': 1000.0,
#  'EX_cpd00281_e': 1000.0,
#  'EX_cpd00280_e': 1000.0,
#  'EX_cpd00249_e': 1000.0,
#  'EX_cpd00246_e': 1000.0,
#  'EX_cpd00184_e': 1000.0,
#  'EX_cpd00211_e': 1000.0,
#  'EX_cpd00142_e': 1000.0,
#  'EX_cpd02042_e': 1000.0,
#  'EX_cpd00781_e': 1000.0,
#  'EX_cpd14472_e': 1000.0,
#  'EX_CPD1344_e': 1000.0,
#  'EX_cpd11585_e': 1000.0,
#  'EX_CPD1350_e': 1000.0,
#  'EX_CPD1353_e': 1000.0,
#  'EX_CPD1356_e': 1000.0,
#  'EX_cpd00300_e': 1000.0,
#  'EX_cpd01217_e': 1000.0,
#  'EX_cpd00311_e': 1000.0,
#  'EX_cpd00367_e': 1000.0,
#  'EX_cpd00122_e': 1000.0,
#  'EX_cpd00152_e': 1000.0,
#  'EX_cpd00274_e': 1000.0,
#  'EX_cpd00186_e': 1000.0,
#  'EX_cpd00069_e': 1000.0,
#  'EX_CPD1380_e': 1000.0,
#  'EX_cpd11591_e': 1000.0,
#  'EX_CPD1386_e': 1000.0,
#  'EX_cpd11580_e': 1000.0,
#  'EX_CPD1392_e': 1000.0,
#  'EX_CPD1395_e': 1000.0,
#  'EX_cpd11583_e': 1000.0,
#  'EX_cpd11584_e': 1000.0,
#  'EX_CPD1404_e': 1000.0,
#  'EX_cpd11587_e': 1000.0,
#  'EX_CPD1410_e': 1000.0,
#  'EX_CPD1413_e': 1000.0,
#  'EX_CPD1416_e': 1000.0,
#  'EX_cpd01092_e': 1000.0,
#  'EX_cpd00312_e': 1000.0,
#  'EX_cpd00550_e': 1000.0,
#  'EX_cpd00549_e': 1000.0,
#  'EX_cpd01308_e': 1000.0,
#  'EX_cpd00421_e': 1000.0,
#  'EX_cpd00012_e': 1000.0,
#  'EX_cpd00146_e': 1000.0,
#  'EX_cpd00482_e': 1000.0,
#  'EX_cpd00126_e': 1000.0,
#  'EX_cpd00061_e': 1000.0,
#  'EX_cpd00079_e': 1000.0,
#  'EX_cpd00288_e': 1000.0,
#  'EX_cpd00046_e': 1000.0,
#  'EX_cpd00235_e': 1000.0,
#  'EX_cpd00738_e': 1000.0,
#  'EX_cpd00091_e': 1000.0,
#  'EX_cpd00298_e': 1000.0,
#  'EX_cpd01622_e': 1000.0,
#  'EX_cpd01908_e': 1000.0,
#  'EX_cpd00727_e': 1000.0,
#  'EX_cpd00284_e': 1000.0,
#  'EX_cpd00696_e': 1000.0,
#  'EX_cpd03535_e': 1000.0,
#  'EX_cpd01665_e': 1000.0,
#  'EX_cpd03912_e': 1000.0,
#  'EX_cpd01550_e': 1000.0,
#  'EX_cpd00285_e': 1000.0,
#  'EX_cpd00074_e': 1000.0,
#  'EX_cpd00587_e': 1000.0,
#  'EX_cpd01414_e': 1000.0,
#  'EX_cpd03805_e': 1000.0,
#  'EX_cpd00455_e': 1000.0,
#  'EX_cpd00155_e': 1000.0,
#  'EX_cpd00745_e': 1000.0,
#  'EX_cpd00250_e': 1000.0,
#  'EX_cpd03385_e': 1000.0,
#  'EX_cpd08928_e': 1000.0,
#  'EX_cpd00424_e': 1000.0,
#  'EX_cpd00637_e': 1000.0,
#  'EX_cpd00406_e': 1000.0,
#  'EX_cpd00652_e': 1000.0,
#  'EX_CPD1524_e': 1000.0,
#  'EX_tre_e': 1000.0,
#  'EX_man_e': 1000.0,
#  'EX_galt_e': 1000.0,
#  'EX_arab__L_e': 1000.0,
#  'EX_acgam_e': 1000.0,
#  'EX_glcr_e': 1000.0,
#  'EX_succ_e': 1000.0,
#  'EX_gal_e': 1000.0,
#  'EX_asp__L_e': 1000.0,
#  'EX_pro__L_e': 1000.0,
#  'EX_ala__D_e': 1000.0,
#  'EX_ser__D_e': 1000.0,
#  'EX_for_e': 1000.0,
#  'EX_mnl_e': 1000.0,
#  'EX_glu__L_e': 1000.0,
#  'EX_sbt__D_e': 1000.0,
#  'EX_glyc_e': 1000.0,
#  'EX_fuc__L_e': 1000.0,
#  'EX_glcur_e': 1000.0,
#  'EX_glcn_e': 1000.0,
#  'EX_glyc3p_e': 1000.0,
#  'EX_xyl__D_e': 1000.0,
#  'EX_lac__L_e': 1000.0,
#  'EX_g6p_e': 1000.0,
#  'EX_malt_e': 1000.0,
#  'EX_melib_e': 1000.0,
#  'EX_thymd_e': 1000.0,
#  'EX_galctn__D_e': 1000.0,
#  'EX_rib__D_e': 1000.0,
#  'EX_rmn_e': 1000.0,
#  'EX_fru_e': 1000.0,
#  'EX_ac_e': 1000.0,
#  'EX_glc__D_e': 1000.0,
#  'EX_asn__L_e': 1000.0,
#  'EX_sucr_e': 1000.0,
#  'EX_uri_e': 1000.0,
#  'EX_12ppd__S_e': 1000.0,
#  'EX_akg_e': 1000.0,
#  'EX_lcts_e': 1000.0,
#  'EX_gln__L_e': 1000.0,
#  'EX_malttr_e': 1000.0,
#  'EX_dad_2_e': 1000.0,
#  'EX_adn_e': 1000.0,
#  'EX_g1p_e': 1000.0,
#  'EX_f6p_e': 1000.0,
#  'EX_ins_e': 1000.0,
#  'EX_cit_e': 1000.0,
#  'EX_inost_e': 1000.0,
#  'EX_fum_e': 1000.0,
#  'EX_ppa_e': 1000.0,
#  'EX_galct__D_e': 1000.0,
#  'EX_glyclt_e': 1000.0,
#  'EX_mal__D_e': 1000.0,
#  'EX_mal__L_e': 1000.0,
#  'EX_ser__L_e': 1000.0,
#  'EX_thr__L_e': 1000.0,
#  'EX_ala__L_e': 1000.0,
#  'EX_acac_e': 1000.0,
#  'EX_acmana_e': 1000.0,
#  'EX_galur_e': 1000.0,
#  'EX_peamn_e': 1000.0,
#  'EX_etha_e': 1000.0,
#  'EX_tym_e': 1000.0,
#  'EX_lyx__L_e': 1000.0,
#  'EX_pyr_e': 1000.0,
#  'EX_galctn__L_e': 1000.0,
#  'EX_acnam_e': 1000.0,
#  'EX_all__D_e': 1000.0,
#  'EX_4abut_e': 1000.0,
#  'EX_but_e': 1000.0,
#  'EX_dca_e': 1000.0,
#  'EX_5dglcn_e': 1000.0,
#  'EX_hxa_e': 1000.0,
#  'EX_tartr__L_e': 1000.0,
#  'EX_leu__L_e': 1000.0,
#  'EX_lys__L_e': 1000.0,
#  'EX_met__L_e': 1000.0,
#  'EX_arg__L_e': 1000.0,
#  'EX_gly_e': 1000.0,
#  'EX_his__L_e': 1000.0,
#  'EX_hom__L_e': 1000.0,
#  'EX_ile__L_e': 1000.0,
#  'EX_orn_e': 1000.0,
#  'EX_phe__L_e': 1000.0,
#  'EX_val__L_e': 1000.0,
#  'EX_ptrc_e': 1000.0,
#  'EX_dha_e': 1000.0,
#  'EX_cys__L_e': 1000.0,
#  'EX_nh4_e': 1000.0,
#  'EX_no2_e': 1000.0,
#  'EX_no3_e': 1000.0,
#  'EX_urea_e': 1000.0,
#  'EX_trp__L_e': 1000.0,
#  'EX_tyr__L_e': 1000.0,
#  'EX_agm_e': 1000.0,
#  'EX_acgal_e': 1000.0,
#  'EX_gam_e': 1000.0,
#  'EX_ura_e': 1000.0,
#  'EX_ade_e': 1000.0,
#  'EX_cytd_e': 1000.0,
#  'EX_csn_e': 1000.0,
#  'EX_gua_e': 1000.0,
#  'EX_gsn_e': 1000.0,
#  'EX_thym_e': 1000.0,
#  'EX_xan_e': 1000.0,
#  'EX_xtsn_e': 1000.0,
#  'EX_alltn_e': 1000.0,
#  'EX_23camp_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_3amp_e': 1000.0,
#  'EX_gmp_e': 1000.0,
#  'EX_23cgmp_e': 1000.0,
#  'EX_3gmp_e': 1000.0,
#  'EX_cmp_e': 1000.0,
#  'EX_23ccmp_e': 1000.0,
#  'EX_gam6p_e': 1000.0,
#  'EX_3cmp_e': 1000.0,
#  'EX_ump_e': 1000.0,
#  'EX_23cump_e': 1000.0,
#  'EX_man6p_e': 1000.0,
#  'EX_pser__L_e': 1000.0,
#  'EX_thrp_e': 1000.0,
#  'EX_3ump_e': 1000.0,
#  'EX_tyrp_e': 1000.0,
#  'EX_minohp_e': 1000.0,
#  'EX_etoh_e': 1000.0}

# %%
#To prepare for cobrapy gapfilling: 
#parse out the metabolites that do have growth and convert into list
#read in the CSV file with the list of metabolites to add, starting with biolog
biolog_df = pd.read_csv('../rhodobacter/data/growth/biolog_results.csv')

# Filter the DataFrame for rows where the 'uptake' column is greater than 0
filtered_biolog_df = biolog_df[biolog_df['uptake'] > 0]

# Extract the list of exchange reactions
biolog_id = filtered_biolog_df['exchange'].tolist()

#define universal model to pull reactions from
universal = cobra.Model("universal_reactions")
print(universal.optimize().objective_value)

display(filtered_biolog_df)
#use this list test one reaction at a time
# Out:
# 0.0
#            exchange  growth  uptake
# 3         EX_succ_e    True      10
# 5        EX_asp_L_e    True      10
# 6        EX_pro_L_e    True      10
# 9          EX_man_e    True      10
# 10        EX_galt_e    True      10
# 12       EX_sbt_D_e    True      10
# 13        EX_glyc_e    True      10
# 15       EX_glcur_e    True      10
# 17       EX_xyl_D_e    True      10
# 18       EX_lac_D_e    True      10
# 19         EX_for_e    True      10
# 20         EX_mnl_e    True      10
# 21       EX_glu_L_e    True      10
# 22       EX_rib_D_e    True      10
# 25      EX_glc_aD_e    True      10
# 28       EX_thymd_e    True      10
# 29       EX_asp_D_e    True      10
# 31         EX_akg_e    True      10
# 32       EX_2obut_e    True      10
# 35         EX_uri_e    True      10
# 36       EX_gln_L_e    True      10
# 39       EX_2hbut_e    True      10
# 41         EX_rbt_e    True      10
# 44         EX_adn_e    True      10
# 45   EX_gly_asp_L_e    True      10
# 48         EX_fum_e    True      10
# 49         EX_ppa_e    True      10
# 52         EX_glx_e    True      10
# 54         EX_ins_e    True      10
# 58       EX_ala_L_e    True      10
# 59      EX_alagly_e    True      10
# 60        EX_acac_e    True      10
# 62    EX_methsucc_e    True      10
# 63       EX_mal_D_e    True      10
# 64       EX_mal_L_e    True      10
# 65      EX_glypro_e    True      10
# 69       EX_lyx_L_e    True      10
# 70         EX_pyr_e    True      10
# 71       EX_galur_e    True      10
# 73        EX_etha_e    True      10
# 78     EX_dextrin_e    True      10
# 81      EX_pectin_e    True      10
# 85      EX_abt__D_e    True      10
# 88        EX_drib_e    True      10
# 102        EX_but_e    True      10
# 107        EX_gam_e    True      10
# 112     EX_5dglcn_e    True      10
# 117    EX_tatr__L_e    True      10
# 119      EX_alamd_e    True      10
# 125     EX_ile__L_e    True      10
# 126     EX_Leu__L_e    True      10
# 131     EX_5oxpro_e    True      10
# 132     EX_val__L_e    True      10
# 134        EX_dha_e    True      10

# %%
#ADD FIRST BIOLOG EXCHANGE REACTION TO UNIVERSAL MODEL
universal = cobra.Model("universal_reactions") #grabs universal model from cobra

# Define the exchange reaction
exchange_reaction = cobra.Reaction("EX_cpd00036_e")
exchange_reaction.name = "Exchange reaction for cpd00036"
exchange_reaction.lower_bound = -1000  # Allow uptake
exchange_reaction.upper_bound = 1000   # Allow secretion

# Define the metabolite involved in the exchange reaction
metabolite = cobra.Metabolite(
    "cpd00036",
    formula="C4H4O4",
    name="Succinate",
    compartment="e"
)

# Add the metabolite to the exchange reaction
exchange_reaction.add_metabolites({metabolite: -1})

# Add the exchange reaction to the universal model
universal.add_reactions([exchange_reaction])

# Save the model to a new file with the desired name
universal_with_biolog = "../GEMS/universal_with_biolog.xml"
cobra.io.write_sbml_model(universal, universal_with_biolog)

# Load the model from the saved file
universal_with_biolog = cobra.io.read_sbml_model(universal_with_biolog)

#optimize model and print objective value
solution = universal_with_biolog.optimize()
print(solution.objective_value)
# Out:
# No objective coefficients in model. Unclear what should be optimized
# 0.0

# %%
#ADDING REACTION WHERE METABOLITEN IS ALREADY DEFINED IN UNIVERSAL MODEL 
# for i in [i.id for i in model.metabolites.succinate.reactions]: #iterates through all reactions that f6p is involved in F6p metabolites
#     reaction = model.reactions.get_by_id(i)
#     universal.add_reactions([reaction.copy()])
#     model.remove_reactions([reaction]) #adds f6p reactions to universal model and removes them from our working model
# cobra.io.write_sbml_model(universal, "../GEMs/f6p_reactions.xml") #universal model with f6p
# cobra.io.write_sbml_model(model, "../GEMs/model_with_f6p_gap.xml") #model without f6p so should not grow

#test to see if gapped model grows
# reaction = exchange_reaction
# working_model.remove_reactions([exchange_reaction])
# working_model_with_gap = cobra.io.read_sbml_model("../GEMs/working_model_with_gap.xml")
# working_model_with_gap.optimize()

# %%
#run gapfill to replace removed metabolite into working model: view reactions to add
solutions = gapfill(working_model, universal_with_biolog, demand_reactions=False)
for reaction in solutions[0]:
    print(reaction.id)

# %%
#run gapfill to replace removed metabolite into working model: take first element of solutions and add
model_gapfilled = working_model.copy()
model_gapfilled.add_reactions(solutions[0])
cobra.io.write_sbml_model(model_gapfilled, "../GEMs/model_gapfilled.xml")

# %%
#optimize gapfilled model to make sure it grows
model_gapfilled.optimize().objective_value
#assert to optimize.solutions() compared to final model
model_gapfilled.reactions.get_by_id('EX_cpd00036_e')
# Out:
# <Reaction EX_cpd00036_e at 0x215263af710>
